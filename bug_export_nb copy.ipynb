# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

bug_df = pd.read_csv('My_Requests_01_12_2022_10_20.csv', index_col='Key', parse_dates=['Created', 'Updated'])
bug_df['Created'] = bug_df['Created'].dt.date
bug_df['Updated'] = bug_df['Updated'].dt.date
bug_df = bug_df.sort_values(by=('Priority'), ascending=True)
bug_df.head()
# Out:
#                   Type         Reporter     Created  \
# Key
# CP-70569  Report a Bug     Jake Daylong  2022-11-16
# CP-70495  Report a Bug        Tim Stien  2022-11-15
# CP-70654  Report a Bug  Dmitry Ischenko  2022-11-17
# CP-71001  Report a Bug     Jake Daylong  2022-11-23
# CP-71021  Report a Bug  Dmitry Ischenko  2022-11-23
#
#                                                     Summary           Status  \
# Key
# CP-70569                       Batch Processing Not Working         Resolved
# CP-70495            Country Codes do not meet ISO standards         Resolved
# CP-70654     E-mail Notifications are not getting generated  Customer Action
# CP-71001  LATAM Ship Statement prints on Ship Request bu...      In Progress
# CP-71021  Unable to view or modify user in system.  Pote...      In Progress
#
#          Priority Resolution     Updated               Assignee
# Key
# CP-70569  Blocker      Fixed  2022-11-17          Sandeep Yerra
# CP-70495  Blocker      Fixed  2022-11-22     Venakata Rao Nakka
# CP-70654  Blocker        NaN  2022-11-24  Amarnath Reddy Ambati
# CP-71001  Blocker        NaN  2022-11-29      Jangam, Poojitha
# CP-71021  Blocker        NaN  2022-11-30           suresh.katta

# %%
prev_export = pd.read_csv('bugs_aging.csv', index_col='Key', parse_dates=['Created', 'Updated'])
#prev_export = pd.read_csv('bugs_export.csv', index_col='Key', parse_dates=['Created', 'Updated'])
prev_export['Created'] = prev_export['Created'].dt.date
prev_export['Updated'] = prev_export['Updated'].dt.date
prev_export.head(60)

# %%
resolved = pd.DataFrame(prev_export)

# %%
#new_export = pd.concat([bug_df, prev_export]).drop_duplicates(subset='', keep=False)
new_export = bug_df.loc[bug_df.index.difference(prev_export.index)]
new_export.head(60)
# Out:
#                   Type      Reporter     Created  \
# Key
# CP-71214  Report a Bug  Jake Daylong  2022-11-29
# CP-71263  Report a Bug  Jake Daylong  2022-11-30
# CP-71265  Report a Bug  Jake Daylong  2022-11-30
#
#                                                     Summary       Status  \
# Key
# CP-71214  Return labels should generate at Ship Request ...  In Progress
# CP-71263  Turn off ITN validation for ship request creation  In Progress
# CP-71265     Canadian Province Abbreviation Codes incorrect  In Progress
#
#          Priority Resolution     Updated         Assignee
# Key
# CP-71214    Major        NaN  2022-11-30  Sivaji Ikkurthi
# CP-71263    Major        NaN  2022-11-30    Sandeep Yerra
# CP-71265    Major        NaN  2022-11-30    Sandeep Yerra

# %%
with pd.ExcelWriter('bugs_export.xlsx', mode='a', engine='openpyxl', if_sheet_exists='overlay') as writer:
    new_export.to_excel(writer, sheet_name='Sheet1', header=None, startrow=writer.sheets['Sheet1'].max_row, index=True)
